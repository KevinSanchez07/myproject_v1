# %% [markdown]
# # REQUEST LOCAL

# %%
# Name:              api_test.py
# Developers:        Kevin Alexander Martinez Sanchez
# Creation date:     30th September of 2022
# Modification date: 31th September of 2022
# Diagram link:      https://lucid.app/lucidchart/20424413-1db2-43f5-80e2-0c32365da439/edit?viewport_loc=44%2C-12%2C1579%2C776%2C0_0&invitationId=inv_b9af206f-1e47-4e1c-b953-c44427f45df8

import json
import flask
import requests
import builtins
import traceback
import pandas as pd
from helpers.constants import API_URL, TABLE, dynamodb_client
import time


def get_pages_dynamo_data_batches(date_=None):

    try:
        paginator = dynamodb_client.get_paginator('scan')
        operation_parameters = {
            'TableName': TABLE
        }

        page_iterator = paginator.paginate(**operation_parameters)
        pages = []

        for page in page_iterator:
            pages.append(page)

        return pages
    except Exception as e:
        return f"{e}\n\n{traceback.format_exc()}"


def convert_dynamo_data_to_df(scan):

    if scan is None:
        return None

    columns = list(scan['Items'][0].keys())
    df_dynamo = pd.DataFrame(columns=columns)

    for item in scan['Items']:
        dict_ = {}
        for key_ in item.keys():
            temp = item[key_]
            for key_type in temp:
                dict_[key_] = temp[key_type]
        df_dynamo.loc[df_dynamo.shape[0]] = dict_

    return df_dynamo


def get_all_dynamo_db_data(date_=None):
    try:
        pages = get_pages_dynamo_data_batches(date_)
        all_data_dfs = [
            convert_dynamo_data_to_df(page) for page in pages
        ]

        df_dynamo = pd.concat(all_data_dfs).reset_index(drop=True)

        return df_dynamo
    except Exception as e:
        return f"{e}\n\n{traceback.format_exc()}"
    

def get_data():
    try:
        data = requests.get(API_URL).json()
        return data
    except Exception as e:
        return f'error: {e}'


def data_to_df(data:dict):
    try:
        df = pd.DataFrame(data['results'])
        return df
    except Exception as e:
        error = 'data incorrecta'
        return f'error: {error}, {e}'
    
    
def get_request(request):
    str_to_dict = '{' + request + '}'
    json_request = json.dumps(str_to_dict)
    str_to_dict = json_request.replace("\'", "\"")
    print(str_to_dict)
    request_ = json.loads(str_to_dict)
    res = json.loads(request_)
    print(f"Request: {res}")
    customer_id = res.get("customer_id")
    
    try:
        obtain_data = get_data()
        df = data_to_df(obtain_data)
        df_dynamo = get_all_dynamo_db_data()
        df_concat = pd.concat([df, df_dynamo], axis=1, join="inner")
        df_search = df_concat[df_concat['customer_id'] == customer_id]
        value_cash = str(df_search.cash_amount.to_list()).replace('[', '').replace(']', '')
        value_customer_id = str(df_search.customer_id.to_list()).replace('[', '').replace(']', '')
        value_date = str(df_search.ex_dividend_date.to_list()).replace('[', '').replace(']', '')
        value_money = str(df_search.currency.to_list()).replace('[', '').replace(']', '')

        builtins.customer_id = customer_id

        if value_customer_id == '':
            request_data = {"data": {"customer_id": 'customer not found'}}
        else:
            request_data = {"data": {"customer_id": value_customer_id,
                                     "value_cash": value_cash,
                                     "value_date": value_date,
                                     "value_money": value_money
                                     }
                            }
        return request_data, df_search
    except Exception as e:
        print(e)

              
def pd_read_s3_csv(key, sep=','):
    """ Read single csv file from S3 """

    obj = s3_client.get_object(Bucket=BUCKET, Key=key)
    df = pd.read_csv(
        BytesIO(obj['Body'].read()),
        sep=sep
    )
    return df


def send_df_to_s3(df, key):
    csv_buffer = StringIO()
    df.to_csv(csv_buffer, index=False)
    s3_resource.Object(BUCKET, key).put(Body=csv_buffer.getvalue())
              

def df_to_local(df, path:str):
    path_document = path + 'document_validation.csv'
    df.to_csv(path_document, sep=',', encoding='utf-8', index=False)
    return f'write document in {path_document}'


def hello():
    return "Hello World!"


def main(request:dict):
    try:
        request = get_request(request)
        print(request)
        return "status 200"
    except Exception as e:
        print(e)

# %%
test_data = {'data': {'customer_id': '1123'}}

# %%
main(test_data)
# Out:
# Request: {'data': {'customer_id': '1123'}}
# {'data': {'customer_id': "'1123'", 'value_cash': '0.59375', 'value_date': "'2025-06-12'", 'value_money': "'USD'"}}
# 'status 200'

# %%
get_all_dynamo_db_data()
# Out:
#    customer_id                                      business_info  \
# 0         1123  {"business_information": {"id": 991, "created_...
# 1          760  {"business_information": {"id": 661, "created_...
# 2         1092  {"business_information": {"id": 960, "created_...
# 3         1156  {"business_information": {"id": 1024, "created...
# 4         1157  {"business_information": {"id": 1025, "created...
# 5          694  {"business_information": {"id": 595, "created_...
# 6           13  {"business_information": {"id": 10, "created_a...
# 7         1057  {"business_information": {"id": 925, "created_...
# 8          628  {"business_information": {"id": 529, "created_...
# 9            1  {"business_information": {"id": 1, "created_at...
# 10         266  {"business_information": {"id": 266, "created_...
# 11         133  {"business_information": {"id": 133, "created_...
# 12        1158  {"business_information": {"id": 1026, "created...
# 13         397  {"business_information": {"id": 364, "created_...
# 14         331  {"business_information": {"id": 331, "created_...
# 15         232  {"business_information": {"id": 232, "created_...
# 16         860  {"business_information": {"id": 761, "created_...
# 17         727  {"business_information": {"id": 628, "created_...
# 18        1090  {"business_information": {"id": 958, "created_...
# 19         629  {"business_information": {"id": 531, "created_...
# 20        test                                    "business_info"
# 21         662  {"business_information": {"id": 563, "created_...
# 22        1091  {"business_information": {"id": 959, "created_...
# 23         926  {"business_information": {"id": 826, "created_...
# 24         564  {"business_information": {"id": 498, "created_...
# 25        1190  {"business_information": {"id": 1058, "created...
# 26         100  {"business_information": {"id": 100, "created_...
# 27         859  {"business_information": {"id": 760, "created_...
# 28         199  {"business_information": {"id": 199, "created_...
# 29          34  {"business_information": {"id": 34, "created_a...
# 30         101  {"business_information": {"id": 101, "created_...
# 31         661  {"business_information": {"id": 562, "created_...
# 32        1222  {"business_information": {"id": 1090, "created...
# 33          11  {"business_information": {"id": 9, "created_at...
# 34           3  {"business_information": {"id": 3, "created_at...
# 35        1024  {"business_information": {"id": 892, "created_...
# 36         134  {"business_information": {"id": 134, "created_...
# 37          67  {"business_information": {"id": 67, "created_a...
# 38         892  {"business_information": {"id": 793, "created_...
# 39         991  {"business_information": {"id": 859, "created_...
# 40          15  {"business_information": {"id": 12, "created_a...
# 41         166  {"business_information": {"id": 166, "created_...
# 42        1159  {"business_information": {"id": 1027, "created...
# 43         463  {"business_information": {"id": 430, "created_...
# 44          14  {"business_information": {"id": 11, "created_a...
# 45       test1                                    "business_info"
#
#                                                tokens
# 0   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 1   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 2   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 3   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 4   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 5   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 6   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 7   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
# 8   AQECAHiazhTtSNTTix5gxR/KsCqNZ2KY7ScAMYJtf2Kv5l...
